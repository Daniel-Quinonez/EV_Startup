# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df = pd.read_csv('EV_Original.csv')
df.dropna(inplace =  True)
print(df.to_string)
print(df.corr())
# Out:
# <bound method DataFrame.to_string of      category/model  Affordability  Profitability   Sales  Range  \
# 0           tesla 3              5           9500  211641    272
# 1        rivian RT1              4        -150000   20332    230
# 2        lucid pure              4         -95755   34000    410
# 4           kia EV6              5           1200   80000    310
# 7   hyundai ioniq 5              5            780   23000    220
# 8            bmw i4              5           3200   10000    256
# 9        audi etron              5           1700    7503    225
# 11    chevy bolt EV              6           1900   38120    259
# 12      ford mach e              5           -200   39458    290
# 16       mazda mx30              5           -600     324    100
# 18  subaru solterra              5           -300     919    228
# 19    gmc hummer ev              4           6200   40000    329
# 21        draco gte              1         125000       0    250
# ...

# %%
df.columns
# Out:
# Index(['category/model', 'Affordability', 'Profitability', 'Sales', 'Range',
#        'Total production thousands', 'Time to produce (weeks)',
#        'Monthly payment', 'Type'],
#       dtype='object')

# %%
sns.regplot(df['Affordability'],df['Profitability'])
# Out:
# C:\Users\Bruno\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Affordability', ylabel='Profitability'>

# %% [markdown]
# The plot shows the overall relationship between affordability and profitability (not as linear as we thought)

# %%
sns.regplot(df['Profitability'],df['Monthly payment'])
# Out:
# <AxesSubplot:xlabel='Profitability', ylabel='Monthly payment'>

# %% [markdown]
# The plot demonstrates the correlation between profitability and monthly payment (Even less linear pushing us to classification)

# %%
df.columns
# Out:
# Index(['category/model', 'Affordability', 'Profitability', 'Sales', 'Range',
#        'Total production thousands', 'Time to produce (weeks)',
#        'Monthly payment', 'Type'],
#       dtype='object')

# %%
df.Affordability.hist()
# Out:
# <AxesSubplot:>

# %%
df.Sales.hist()
# Out:
# <AxesSubplot:>

# %%
df.Profitability.hist()
# Out:
# <AxesSubplot:>

# %%
df.columns
# Out:
# Index(['category/model', 'Affordability', 'Profitability', 'Sales', 'Range',
#        'Total production thousands', 'Time to produce (weeks)',
#        'Monthly payment', 'Type'],
#       dtype='object')

# %%
print(df.corr())
# Out:
#                             Affordability  Profitability     Sales     Range  \
# Affordability                    1.000000      -0.721178  0.328305 -0.270214
# Profitability                   -0.721178       1.000000 -0.212680  0.205640
# Sales                            0.328305      -0.212680  1.000000  0.197204
# Range                           -0.270214       0.205640  0.197204  1.000000
# Total production thousands       0.180818      -0.073277  0.934581  0.035887
# Time to produce (weeks)         -0.226336       0.025583 -0.151583  0.162751
# Monthly payment                 -0.925566       0.913053 -0.314889  0.248966
#
#                             Total production thousands  \
# Affordability                                 0.180818
# Profitability                                -0.073277
# Sales                                         0.934581
# Range                                         0.035887
# Total production thousands                    1.000000
# ...

# %%
sns.regplot(df['Profitability'],df['Range'])
# Out:
# C:\Users\Bruno\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Profitability', ylabel='Range'>

# %%
sns.regplot(df['Monthly payment'],df['Range'])
# Out:
# <AxesSubplot:xlabel='Monthly payment', ylabel='Range'>

# %%
sns.regplot(df['Monthly payment'],df['Profitability'])
# Out:
# <AxesSubplot:xlabel='Monthly payment', ylabel='Profitability'>
